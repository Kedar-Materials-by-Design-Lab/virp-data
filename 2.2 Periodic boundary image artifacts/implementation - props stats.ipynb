# %% [markdown]
# ## Init and functions

# %%
from pymatgen.core.structure import Structure
import os
import csv
import torch
import matgl
from chgnet.model.model import CHGNet
from chgnet.model import StructOptimizer
from chgnet.model.dynamics import MolecularDynamics

def calculate_properties_and_write_csv(folder_path, output_csv):
    # Load the MEGNet band gap model
    bandgap_model = matgl.load_model("MEGNet-MP-2019.4.1-BandGap-mfi")
    
    # Load the CHGNet model for total energy prediction
    chgnet = CHGNet.load()

    # Initialize data storage
    data = []

    for filename in os.listdir(folder_path):
        if filename.endswith(".cif"):
            filepath = os.path.join(folder_path, filename)
            try:
                # Load the structure
                structure = Structure.from_file(filepath)
                
                # Predict total energy
                total_energy = chgnet.predict_structure(structure)['e']

                # Calculate density and convert to float
                density = float(structure.density)

                # Predict band gaps for different methods
                bandgaps = {}
                for i, method in ((0, "PBE"), (1, "GLLB-SC"), (2, "HSE"), (3, "SCAN")):
                    graph_attrs = torch.tensor([i])
                    bandgap = bandgap_model.predict_structure(structure=structure, state_attr=graph_attrs)
                    bandgaps[method] = float(bandgap)
                
                # Append results to data
                data.append({
                    "File": filename,
                    "Total Energy (eV)": total_energy,
                    "Density": density,
                    "PBE Bandgap (eV)": bandgaps["PBE"],
                    "GLLB-SC Bandgap (eV)": bandgaps["GLLB-SC"],
                    "HSE Bandgap (eV)": bandgaps["HSE"],
                    "SCAN Bandgap (eV)": bandgaps["SCAN"],
                })
                
                print(f"Processed: {filename}")
            
            except Exception as e:
                print(f"Error processing {filename}: {e}")
    
    # Write results to CSV
    with open(output_csv, mode='w', newline='') as csvfile:
        fieldnames = ["File", "Total Energy (eV)", "Density", "PBE Bandgap (eV)", "GLLB-SC Bandgap (eV)", "HSE Bandgap (eV)", "SCAN Bandgap (eV)"]
        writer = csv.DictWriter(csvfile, fieldnames=fieldnames)
        
        writer.writeheader()
        writer.writerows(data)

    print(f"Results saved to {output_csv}")

# %%
# Example usage
folder_path = "1000-3x"
output_csv = "1000-3x.csv"
calculate_properties_and_write_csv(folder_path, output_csv)
# Out:
# CHGNet v0.3.0 initialized with 412,525 parameters
# CHGNet will run on cuda:0
# /opt/anaconda3/envs/msml/lib/python3.9/site-packages/pymatgen/io/cif.py:1229: UserWarning: Issues encountered while parsing CIF: 1 fractional coordinates rounded to ideal values to avoid issues with finite precision.
#   warnings.warn("Issues encountered while parsing CIF: " + "\n".join(self.warnings))
# Processed: geller-wernick_supercell_virtual_843_stropt.cif
# /opt/anaconda3/envs/msml/lib/python3.9/site-packages/pymatgen/io/cif.py:1229: UserWarning: Issues encountered while parsing CIF: 4 fractional coordinates rounded to ideal values to avoid issues with finite precision.
#   warnings.warn("Issues encountered while parsing CIF: " + "\n".join(self.warnings))
# Processed: geller-wernick_supercell_virtual_464_stropt.cif
# Processed: geller-wernick_supercell_virtual_78_stropt.cif
# /opt/anaconda3/envs/msml/lib/python3.9/site-packages/pymatgen/io/cif.py:1229: UserWarning: Issues encountered while parsing CIF: 3 fractional coordinates rounded to ideal values to avoid issues with finite precision.
#   warnings.warn("Issues encountered while parsing CIF: " + "\n".join(self.warnings))
# Processed: geller-wernick_supercell_virtual_603_stropt.cif
# /opt/anaconda3/envs/msml/lib/python3.9/site-packages/pymatgen/io/cif.py:1229: UserWarning: Issues encountered while parsing CIF: 2 fractional coordinates rounded to ideal values to avoid issues with finite precision.
#   warnings.warn("Issues encountered while parsing CIF: " + "\n".join(self.warnings))
# Processed: geller-wernick_supercell_virtual_738_stropt.cif
# Processed: geller-wernick_supercell_virtual_222_stropt.cif
# Processed: geller-wernick_supercell_virtual_469_stropt.cif
# Processed: geller-wernick_supercell_virtual_433_stropt.cif
# Processed: geller-wernick_supercell_virtual_23_stropt.cif
# Processed: geller-wernick_supercell_virtual_508_stropt.cif
# Processed: geller-wernick_supercell_virtual_351_stropt.cif
# Processed: geller-wernick_supercell_virtual_553_stropt.cif
# Processed: geller-wernick_supercell_virtual_140_stropt.cif
# Processed: geller-wernick_supercell_virtual_667_stropt.cif
# Processed: geller-wernick_supercell_virtual_457_stropt.cif
# Processed: geller-wernick_supercell_virtual_173_stropt.cif
# Processed: geller-wernick_supercell_virtual_566_stropt.cif
# Processed: geller-wernick_supercell_virtual_863_stropt.cif
# Processed: geller-wernick_supercell_virtual_801_stropt.cif
# Processed: geller-wernick_supercell_virtual_629_stropt.cif
# Processed: geller-wernick_supercell_virtual_470_stropt.cif
# Processed: geller-wernick_supercell_virtual_461_stropt.cif
# /opt/anaconda3/envs/msml/lib/python3.9/site-packages/pymatgen/io/cif.py:1229: UserWarning: Issues encountered while parsing CIF: 7 fractional coordinates rounded to ideal values to avoid issues with finite precision.
#   warnings.warn("Issues encountered while parsing CIF: " + "\n".join(self.warnings))
# Processed: geller-wernick_supercell_virtual_343_stropt.cif
# Processed: geller-wernick_supercell_virtual_999_stropt.cif
# /opt/anaconda3/envs/msml/lib/python3.9/site-packages/pymatgen/io/cif.py:1229: UserWarning: Issues encountered while parsing CIF: 5 fractional coordinates rounded to ideal values to avoid issues with finite precision.
#   warnings.warn("Issues encountered while parsing CIF: " + "\n".join(self.warnings))
# Processed: geller-wernick_supercell_virtual_277_stropt.cif
# Processed: geller-wernick_supercell_virtual_188_stropt.cif
# Processed: geller-wernick_supercell_virtual_324_stropt.cif
# Processed: geller-wernick_supercell_virtual_998_stropt.cif
# Processed: geller-wernick_supercell_virtual_403_stropt.cif
# Processed: geller-wernick_supercell_virtual_984_stropt.cif
# Processed: geller-wernick_supercell_virtual_755_stropt.cif
# Processed: geller-wernick_supercell_virtual_598_stropt.cif
# Processed: geller-wernick_supercell_virtual_735_stropt.cif
# Processed: geller-wernick_supercell_virtual_899_stropt.cif
# Processed: geller-wernick_supercell_virtual_787_stropt.cif
# Processed: geller-wernick_supercell_virtual_772_stropt.cif
# Processed: geller-wernick_supercell_virtual_386_stropt.cif
# Processed: geller-wernick_supercell_virtual_751_stropt.cif
# Processed: geller-wernick_supercell_virtual_677_stropt.cif
# Processed: geller-wernick_supercell_virtual_498_stropt.cif
# Processed: geller-wernick_supercell_virtual_196_stropt.cif
# Processed: geller-wernick_supercell_virtual_819_stropt.cif
# Processed: geller-wernick_supercell_virtual_490_stropt.cif
# /opt/anaconda3/envs/msml/lib/python3.9/site-packages/pymatgen/io/cif.py:1229: UserWarning: Issues encountered while parsing CIF: 6 fractional coordinates rounded to ideal values to avoid issues with finite precision.
#   warnings.warn("Issues encountered while parsing CIF: " + "\n".join(self.warnings))
# Processed: geller-wernick_supercell_virtual_931_stropt.cif
# Processed: geller-wernick_supercell_virtual_972_stropt.cif
# Processed: geller-wernick_supercell_virtual_24_stropt.cif
# Processed: geller-wernick_supercell_virtual_502_stropt.cif
# Processed: geller-wernick_supercell_virtual_696_stropt.cif
# Processed: geller-wernick_supercell_virtual_276_stropt.cif
# Processed: geller-wernick_supercell_virtual_753_stropt.cif
# Processed: geller-wernick_supercell_virtual_572_stropt.cif
# Processed: geller-wernick_supercell_virtual_206_stropt.cif
# Processed: geller-wernick_supercell_virtual_158_stropt.cif
# Processed: geller-wernick_supercell_virtual_741_stropt.cif
# Processed: geller-wernick_supercell_virtual_7_stropt.cif
# Processed: geller-wernick_supercell_virtual_197_stropt.cif
# Processed: geller-wernick_supercell_virtual_706_stropt.cif
# Processed: geller-wernick_supercell_virtual_969_stropt.cif
# Processed: geller-wernick_supercell_virtual_958_stropt.cif
# Processed: geller-wernick_supercell_virtual_229_stropt.cif
# Processed: geller-wernick_supercell_virtual_290_stropt.cif
# Processed: geller-wernick_supercell_virtual_814_stropt.cif
# Processed: geller-wernick_supercell_virtual_668_stropt.cif
# Processed: geller-wernick_supercell_virtual_821_stropt.cif
# Processed: geller-wernick_supercell_virtual_510_stropt.cif
# Processed: geller-wernick_supercell_virtual_887_stropt.cif
# Processed: geller-wernick_supercell_virtual_655_stropt.cif
# Processed: geller-wernick_supercell_virtual_855_stropt.cif
# Processed: geller-wernick_supercell_virtual_100_stropt.cif
# Processed: geller-wernick_supercell_virtual_763_stropt.cif
# Processed: geller-wernick_supercell_virtual_622_stropt.cif
# Processed: geller-wernick_supercell_virtual_725_stropt.cif
# Processed: geller-wernick_supercell_virtual_310_stropt.cif
# Processed: geller-wernick_supercell_virtual_376_stropt.cif
# Processed: geller-wernick_supercell_virtual_455_stropt.cif
# Processed: geller-wernick_supercell_virtual_265_stropt.cif
# Processed: geller-wernick_supercell_virtual_970_stropt.cif
# Processed: geller-wernick_supercell_virtual_920_stropt.cif
# Processed: geller-wernick_supercell_virtual_51_stropt.cif
# Processed: geller-wernick_supercell_virtual_99_stropt.cif
# Processed: geller-wernick_supercell_virtual_950_stropt.cif
# Processed: geller-wernick_supercell_virtual_726_stropt.cif
# Processed: geller-wernick_supercell_virtual_567_stropt.cif
# Processed: geller-wernick_supercell_virtual_973_stropt.cif
# Processed: geller-wernick_supercell_virtual_568_stropt.cif
# Processed: geller-wernick_supercell_virtual_506_stropt.cif
# Processed: geller-wernick_supercell_virtual_533_stropt.cif
# Processed: geller-wernick_supercell_virtual_704_stropt.cif
# Processed: geller-wernick_supercell_virtual_873_stropt.cif
# Processed: geller-wernick_supercell_virtual_892_stropt.cif
# Processed: geller-wernick_supercell_virtual_765_stropt.cif
# Processed: geller-wernick_supercell_virtual_91_stropt.cif
# Processed: geller-wernick_supercell_virtual_871_stropt.cif
# Processed: geller-wernick_supercell_virtual_907_stropt.cif
# Processed: geller-wernick_supercell_virtual_647_stropt.cif
# Processed: geller-wernick_supercell_virtual_201_stropt.cif
# Processed: geller-wernick_supercell_virtual_705_stropt.cif
# Processed: geller-wernick_supercell_virtual_786_stropt.cif
# Processed: geller-wernick_supercell_virtual_586_stropt.cif
# Processed: geller-wernick_supercell_virtual_473_stropt.cif
# Processed: geller-wernick_supercell_virtual_997_stropt.cif
# Processed: geller-wernick_supercell_virtual_259_stropt.cif
# Processed: geller-wernick_supercell_virtual_124_stropt.cif
# Processed: geller-wernick_supercell_virtual_671_stropt.cif
# Processed: geller-wernick_supercell_virtual_95_stropt.cif
# Processed: geller-wernick_supercell_virtual_628_stropt.cif
# Processed: geller-wernick_supercell_virtual_454_stropt.cif
# Processed: geller-wernick_supercell_virtual_59_stropt.cif
# /opt/anaconda3/envs/msml/lib/python3.9/site-packages/pymatgen/io/cif.py:1229: UserWarning: Issues encountered while parsing CIF: 8 fractional coordinates rounded to ideal values to avoid issues with finite precision.
#   warnings.warn("Issues encountered while parsing CIF: " + "\n".join(self.warnings))
# Processed: geller-wernick_supercell_virtual_337_stropt.cif
# Processed: geller-wernick_supercell_virtual_65_stropt.cif
# Processed: geller-wernick_supercell_virtual_354_stropt.cif
# Processed: geller-wernick_supercell_virtual_691_stropt.cif
# Processed: geller-wernick_supercell_virtual_246_stropt.cif
# Processed: geller-wernick_supercell_virtual_764_stropt.cif
# Processed: geller-wernick_supercell_virtual_985_stropt.cif
# Processed: geller-wernick_supercell_virtual_918_stropt.cif
# Processed: geller-wernick_supercell_virtual_344_stropt.cif
# Processed: geller-wernick_supercell_virtual_993_stropt.cif
# Processed: geller-wernick_supercell_virtual_848_stropt.cif
# Processed: geller-wernick_supercell_virtual_513_stropt.cif
# Processed: geller-wernick_supercell_virtual_275_stropt.cif
# Processed: geller-wernick_supercell_virtual_861_stropt.cif
# Processed: geller-wernick_supercell_virtual_701_stropt.cif
# Processed: geller-wernick_supercell_virtual_453_stropt.cif
# Processed: geller-wernick_supercell_virtual_549_stropt.cif
# Processed: geller-wernick_supercell_virtual_128_stropt.cif
# Processed: geller-wernick_supercell_virtual_496_stropt.cif
# Processed: geller-wernick_supercell_virtual_5_stropt.cif
# Processed: geller-wernick_supercell_virtual_839_stropt.cif
# Processed: geller-wernick_supercell_virtual_347_stropt.cif
# Processed: geller-wernick_supercell_virtual_333_stropt.cif
# Processed: geller-wernick_supercell_virtual_37_stropt.cif
# Processed: geller-wernick_supercell_virtual_775_stropt.cif
# Processed: geller-wernick_supercell_virtual_710_stropt.cif
# Processed: geller-wernick_supercell_virtual_737_stropt.cif
# Processed: geller-wernick_supercell_virtual_981_stropt.cif
# Processed: geller-wernick_supercell_virtual_253_stropt.cif
# Processed: geller-wernick_supercell_virtual_654_stropt.cif
# Processed: geller-wernick_supercell_virtual_939_stropt.cif
# Processed: geller-wernick_supercell_virtual_332_stropt.cif
# Processed: geller-wernick_supercell_virtual_724_stropt.cif
# Processed: geller-wernick_supercell_virtual_64_stropt.cif
# Processed: geller-wernick_supercell_virtual_402_stropt.cif
# Processed: geller-wernick_supercell_virtual_844_stropt.cif
# Processed: geller-wernick_supercell_virtual_274_stropt.cif
# Processed: geller-wernick_supercell_virtual_285_stropt.cif
# Processed: geller-wernick_supercell_virtual_874_stropt.cif
# Processed: geller-wernick_supercell_virtual_608_stropt.cif
# Processed: geller-wernick_supercell_virtual_501_stropt.cif
# Processed: geller-wernick_supercell_virtual_32_stropt.cif
# Processed: geller-wernick_supercell_virtual_487_stropt.cif
# Processed: geller-wernick_supercell_virtual_304_stropt.cif
# Processed: geller-wernick_supercell_virtual_81_stropt.cif
# Processed: geller-wernick_supercell_virtual_925_stropt.cif
# Processed: geller-wernick_supercell_virtual_357_stropt.cif
# Processed: geller-wernick_supercell_virtual_868_stropt.cif
# Processed: geller-wernick_supercell_virtual_420_stropt.cif
# Processed: geller-wernick_supercell_virtual_531_stropt.cif
# Processed: geller-wernick_supercell_virtual_483_stropt.cif
# Processed: geller-wernick_supercell_virtual_155_stropt.cif
# Processed: geller-wernick_supercell_virtual_659_stropt.cif
# Processed: geller-wernick_supercell_virtual_82_stropt.cif
# Processed: geller-wernick_supercell_virtual_19_stropt.cif
# Processed: geller-wernick_supercell_virtual_960_stropt.cif
# Processed: geller-wernick_supercell_virtual_10_stropt.cif
# Processed: geller-wernick_supercell_virtual_203_stropt.cif
# Processed: geller-wernick_supercell_virtual_557_stropt.cif
# Processed: geller-wernick_supercell_virtual_27_stropt.cif
# Processed: geller-wernick_supercell_virtual_456_stropt.cif
# Processed: geller-wernick_supercell_virtual_700_stropt.cif
# Processed: geller-wernick_supercell_virtual_363_stropt.cif
# Processed: geller-wernick_supercell_virtual_367_stropt.cif
# Processed: geller-wernick_supercell_virtual_664_stropt.cif
# Processed: geller-wernick_supercell_virtual_491_stropt.cif
# Processed: geller-wernick_supercell_virtual_193_stropt.cif
# Processed: geller-wernick_supercell_virtual_439_stropt.cif
# Processed: geller-wernick_supercell_virtual_882_stropt.cif
# Processed: geller-wernick_supercell_virtual_370_stropt.cif
# Processed: geller-wernick_supercell_virtual_908_stropt.cif
# Processed: geller-wernick_supercell_virtual_955_stropt.cif
# Processed: geller-wernick_supercell_virtual_556_stropt.cif
# Processed: geller-wernick_supercell_virtual_83_stropt.cif
# Processed: geller-wernick_supercell_virtual_398_stropt.cif
# Processed: geller-wernick_supercell_virtual_909_stropt.cif
# Processed: geller-wernick_supercell_virtual_542_stropt.cif
# Processed: geller-wernick_supercell_virtual_157_stropt.cif
# Processed: geller-wernick_supercell_virtual_435_stropt.cif
# Processed: geller-wernick_supercell_virtual_718_stropt.cif
# Processed: geller-wernick_supercell_virtual_136_stropt.cif
# Processed: geller-wernick_supercell_virtual_728_stropt.cif
# Processed: geller-wernick_supercell_virtual_478_stropt.cif
# Processed: geller-wernick_supercell_virtual_311_stropt.cif
# Processed: geller-wernick_supercell_virtual_585_stropt.cif
# Processed: geller-wernick_supercell_virtual_488_stropt.cif
# Processed: geller-wernick_supercell_virtual_278_stropt.cif
# Processed: geller-wernick_supercell_virtual_288_stropt.cif
# Processed: geller-wernick_supercell_virtual_133_stropt.cif
# Processed: geller-wernick_supercell_virtual_16_stropt.cif
# Processed: geller-wernick_supercell_virtual_773_stropt.cif
# Processed: geller-wernick_supercell_virtual_851_stropt.cif
# Processed: geller-wernick_supercell_virtual_401_stropt.cif
# Processed: geller-wernick_supercell_virtual_990_stropt.cif
# Processed: geller-wernick_supercell_virtual_387_stropt.cif
# Processed: geller-wernick_supercell_virtual_673_stropt.cif
# Processed: geller-wernick_supercell_virtual_944_stropt.cif
# Processed: geller-wernick_supercell_virtual_33_stropt.cif
# Processed: geller-wernick_supercell_virtual_864_stropt.cif
# Processed: geller-wernick_supercell_virtual_291_stropt.cif
# Processed: geller-wernick_supercell_virtual_62_stropt.cif
# Processed: geller-wernick_supercell_virtual_85_stropt.cif
# Processed: geller-wernick_supercell_virtual_885_stropt.cif
# Processed: geller-wernick_supercell_virtual_535_stropt.cif
# /opt/anaconda3/envs/msml/lib/python3.9/site-packages/pymatgen/io/cif.py:1229: UserWarning: Issues encountered while parsing CIF: 9 fractional coordinates rounded to ideal values to avoid issues with finite precision.
#   warnings.warn("Issues encountered while parsing CIF: " + "\n".join(self.warnings))
# Processed: geller-wernick_supercell_virtual_442_stropt.cif
# Processed: geller-wernick_supercell_virtual_153_stropt.cif
# Processed: geller-wernick_supercell_virtual_338_stropt.cif
# Processed: geller-wernick_supercell_virtual_471_stropt.cif
# Processed: geller-wernick_supercell_virtual_260_stropt.cif
# Processed: geller-wernick_supercell_virtual_943_stropt.cif
# Processed: geller-wernick_supercell_virtual_625_stropt.cif
# Processed: geller-wernick_supercell_virtual_537_stropt.cif
# Processed: geller-wernick_supercell_virtual_690_stropt.cif
# Processed: geller-wernick_supercell_virtual_811_stropt.cif
# Processed: geller-wernick_supercell_virtual_87_stropt.cif
# Processed: geller-wernick_supercell_virtual_699_stropt.cif
# Processed: geller-wernick_supercell_virtual_522_stropt.cif
# Processed: geller-wernick_supercell_virtual_803_stropt.cif
# Processed: geller-wernick_supercell_virtual_329_stropt.cif
# Processed: geller-wernick_supercell_virtual_4_stropt.cif
# Processed: geller-wernick_supercell_virtual_407_stropt.cif
# Processed: geller-wernick_supercell_virtual_995_stropt.cif
# Processed: geller-wernick_supercell_virtual_644_stropt.cif
# Processed: geller-wernick_supercell_virtual_199_stropt.cif
# Processed: geller-wernick_supercell_virtual_251_stropt.cif
# Processed: geller-wernick_supercell_virtual_334_stropt.cif
# Processed: geller-wernick_supercell_virtual_809_stropt.cif
# Processed: geller-wernick_supercell_virtual_223_stropt.cif
# Processed: geller-wernick_supercell_virtual_857_stropt.cif
# Processed: geller-wernick_supercell_virtual_183_stropt.cif
# Processed: geller-wernick_supercell_virtual_552_stropt.cif
# Processed: geller-wernick_supercell_virtual_642_stropt.cif
# Processed: geller-wernick_supercell_virtual_286_stropt.cif
# Processed: geller-wernick_supercell_virtual_720_stropt.cif
# Processed: geller-wernick_supercell_virtual_211_stropt.cif
# Processed: geller-wernick_supercell_virtual_318_stropt.cif
# Processed: geller-wernick_supercell_virtual_879_stropt.cif
# Processed: geller-wernick_supercell_virtual_527_stropt.cif
# Processed: geller-wernick_supercell_virtual_169_stropt.cif
# Processed: geller-wernick_supercell_virtual_605_stropt.cif
# Processed: geller-wernick_supercell_virtual_657_stropt.cif
# Processed: geller-wernick_supercell_virtual_377_stropt.cif
# Processed: geller-wernick_supercell_virtual_898_stropt.cif
# Processed: geller-wernick_supercell_virtual_194_stropt.cif
# Processed: geller-wernick_supercell_virtual_900_stropt.cif
# Processed: geller-wernick_supercell_virtual_145_stropt.cif
# Processed: geller-wernick_supercell_virtual_366_stropt.cif
# Processed: geller-wernick_supercell_virtual_250_stropt.cif
# Processed: geller-wernick_supercell_virtual_72_stropt.cif
# Processed: geller-wernick_supercell_virtual_472_stropt.cif
# Processed: geller-wernick_supercell_virtual_837_stropt.cif
# Processed: geller-wernick_supercell_virtual_838_stropt.cif
# Processed: geller-wernick_supercell_virtual_989_stropt.cif
# Processed: geller-wernick_supercell_virtual_174_stropt.cif
# Processed: geller-wernick_supercell_virtual_394_stropt.cif
# Processed: geller-wernick_supercell_virtual_494_stropt.cif
# Processed: geller-wernick_supercell_virtual_58_stropt.cif
# Processed: geller-wernick_supercell_virtual_84_stropt.cif
# Processed: geller-wernick_supercell_virtual_745_stropt.cif
# Processed: geller-wernick_supercell_virtual_448_stropt.cif
# Processed: geller-wernick_supercell_virtual_117_stropt.cif
# Processed: geller-wernick_supercell_virtual_870_stropt.cif
# Processed: geller-wernick_supercell_virtual_2_stropt.cif
# Processed: geller-wernick_supercell_virtual_167_stropt.cif
# Processed: geller-wernick_supercell_virtual_8_stropt.cif
# Processed: geller-wernick_supercell_virtual_592_stropt.cif
# Processed: geller-wernick_supercell_virtual_926_stropt.cif
# Processed: geller-wernick_supercell_virtual_747_stropt.cif
# Processed: geller-wernick_supercell_virtual_331_stropt.cif
# Processed: geller-wernick_supercell_virtual_680_stropt.cif
# Processed: geller-wernick_supercell_virtual_450_stropt.cif
# Processed: geller-wernick_supercell_virtual_176_stropt.cif
# Processed: geller-wernick_supercell_virtual_388_stropt.cif
# Processed: geller-wernick_supercell_virtual_890_stropt.cif
# Processed: geller-wernick_supercell_virtual_788_stropt.cif
# Processed: geller-wernick_supercell_virtual_266_stropt.cif
# Processed: geller-wernick_supercell_virtual_447_stropt.cif
# Processed: geller-wernick_supercell_virtual_670_stropt.cif
# Processed: geller-wernick_supercell_virtual_485_stropt.cif
# Processed: geller-wernick_supercell_virtual_182_stropt.cif
# Processed: geller-wernick_supercell_virtual_208_stropt.cif
# Processed: geller-wernick_supercell_virtual_497_stropt.cif
# Processed: geller-wernick_supercell_virtual_66_stropt.cif
# Processed: geller-wernick_supercell_virtual_328_stropt.cif
# Processed: geller-wernick_supercell_virtual_991_stropt.cif
# Processed: geller-wernick_supercell_virtual_824_stropt.cif
# Processed: geller-wernick_supercell_virtual_12_stropt.cif
# Processed: geller-wernick_supercell_virtual_602_stropt.cif
# Processed: geller-wernick_supercell_virtual_766_stropt.cif
# Processed: geller-wernick_supercell_virtual_889_stropt.cif
# Processed: geller-wernick_supercell_virtual_482_stropt.cif
# Processed: geller-wernick_supercell_virtual_904_stropt.cif
# Processed: geller-wernick_supercell_virtual_480_stropt.cif
# Processed: geller-wernick_supercell_virtual_336_stropt.cif
# Processed: geller-wernick_supercell_virtual_63_stropt.cif
# Processed: geller-wernick_supercell_virtual_202_stropt.cif
# Processed: geller-wernick_supercell_virtual_70_stropt.cif
# Processed: geller-wernick_supercell_virtual_110_stropt.cif
# Processed: geller-wernick_supercell_virtual_30_stropt.cif
# Processed: geller-wernick_supercell_virtual_611_stropt.cif
# Processed: geller-wernick_supercell_virtual_504_stropt.cif
# Processed: geller-wernick_supercell_virtual_135_stropt.cif
# Processed: geller-wernick_supercell_virtual_204_stropt.cif
# Processed: geller-wernick_supercell_virtual_713_stropt.cif
# Processed: geller-wernick_supercell_virtual_102_stropt.cif
# Processed: geller-wernick_supercell_virtual_281_stropt.cif
# Processed: geller-wernick_supercell_virtual_746_stropt.cif
# Processed: geller-wernick_supercell_virtual_479_stropt.cif
# Processed: geller-wernick_supercell_virtual_721_stropt.cif
# Processed: geller-wernick_supercell_virtual_195_stropt.cif
# Processed: geller-wernick_supercell_virtual_760_stropt.cif
# Processed: geller-wernick_supercell_virtual_217_stropt.cif
# Processed: geller-wernick_supercell_virtual_142_stropt.cif
# Processed: geller-wernick_supercell_virtual_578_stropt.cif
# Processed: geller-wernick_supercell_virtual_797_stropt.cif
# Processed: geller-wernick_supercell_virtual_13_stropt.cif
# Processed: geller-wernick_supercell_virtual_214_stropt.cif
# Processed: geller-wernick_supercell_virtual_511_stropt.cif
# Processed: geller-wernick_supercell_virtual_805_stropt.cif
# Processed: geller-wernick_supercell_virtual_350_stropt.cif
# Processed: geller-wernick_supercell_virtual_326_stropt.cif
# Processed: geller-wernick_supercell_virtual_529_stropt.cif
# Processed: geller-wernick_supercell_virtual_961_stropt.cif
# Processed: geller-wernick_supercell_virtual_621_stropt.cif
# Processed: geller-wernick_supercell_virtual_415_stropt.cif
# Processed: geller-wernick_supercell_virtual_593_stropt.cif
# Processed: geller-wernick_supercell_virtual_150_stropt.cif
# Processed: geller-wernick_supercell_virtual_221_stropt.cif
# Processed: geller-wernick_supercell_virtual_682_stropt.cif
# Processed: geller-wernick_supercell_virtual_812_stropt.cif
# Processed: geller-wernick_supercell_virtual_419_stropt.cif
# Processed: geller-wernick_supercell_virtual_982_stropt.cif
# Processed: geller-wernick_supercell_virtual_617_stropt.cif
# Processed: geller-wernick_supercell_virtual_980_stropt.cif
# Processed: geller-wernick_supercell_virtual_379_stropt.cif
# Processed: geller-wernick_supercell_virtual_514_stropt.cif
# Processed: geller-wernick_supercell_virtual_425_stropt.cif
# Processed: geller-wernick_supercell_virtual_856_stropt.cif
# Processed: geller-wernick_supercell_virtual_500_stropt.cif
# Processed: geller-wernick_supercell_virtual_994_stropt.cif
# Processed: geller-wernick_supercell_virtual_335_stropt.cif
# Processed: geller-wernick_supercell_virtual_397_stropt.cif
# Processed: geller-wernick_supercell_virtual_607_stropt.cif
# Processed: geller-wernick_supercell_virtual_543_stropt.cif
# Processed: geller-wernick_supercell_virtual_591_stropt.cif
# Processed: geller-wernick_supercell_virtual_852_stropt.cif
# Processed: geller-wernick_supercell_virtual_807_stropt.cif
# Processed: geller-wernick_supercell_virtual_752_stropt.cif
# Processed: geller-wernick_supercell_virtual_681_stropt.cif
# Processed: geller-wernick_supercell_virtual_606_stropt.cif
# Processed: geller-wernick_supercell_virtual_516_stropt.cif
# Processed: geller-wernick_supercell_virtual_835_stropt.cif
# Processed: geller-wernick_supercell_virtual_68_stropt.cif
# Processed: geller-wernick_supercell_virtual_341_stropt.cif
# Processed: geller-wernick_supercell_virtual_551_stropt.cif
# Processed: geller-wernick_supercell_virtual_20_stropt.cif
# Processed: geller-wernick_supercell_virtual_418_stropt.cif
# Processed: geller-wernick_supercell_virtual_15_stropt.cif
# Processed: geller-wernick_supercell_virtual_748_stropt.cif
# Processed: geller-wernick_supercell_virtual_113_stropt.cif
# Processed: geller-wernick_supercell_virtual_822_stropt.cif
# Processed: geller-wernick_supercell_virtual_662_stropt.cif
# Processed: geller-wernick_supercell_virtual_528_stropt.cif
# Processed: geller-wernick_supercell_virtual_623_stropt.cif
# Processed: geller-wernick_supercell_virtual_779_stropt.cif
# Processed: geller-wernick_supercell_virtual_11_stropt.cif
# Processed: geller-wernick_supercell_virtual_493_stropt.cif
# Processed: geller-wernick_supercell_virtual_791_stropt.cif
# Processed: geller-wernick_supercell_virtual_308_stropt.cif
# Processed: geller-wernick_supercell_virtual_847_stropt.cif
# Processed: geller-wernick_supercell_virtual_679_stropt.cif
# Processed: geller-wernick_supercell_virtual_977_stropt.cif
# Processed: geller-wernick_supercell_virtual_340_stropt.cif
# Processed: geller-wernick_supercell_virtual_358_stropt.cif
# Processed: geller-wernick_supercell_virtual_449_stropt.cif
# Processed: geller-wernick_supercell_virtual_799_stropt.cif
# Processed: geller-wernick_supercell_virtual_467_stropt.cif
# Processed: geller-wernick_supercell_virtual_742_stropt.cif
# Processed: geller-wernick_supercell_virtual_54_stropt.cif
# Processed: geller-wernick_supercell_virtual_131_stropt.cif
# Processed: geller-wernick_supercell_virtual_916_stropt.cif
# Processed: geller-wernick_supercell_virtual_353_stropt.cif
# Processed: geller-wernick_supercell_virtual_446_stropt.cif
# Processed: geller-wernick_supercell_virtual_360_stropt.cif
# Processed: geller-wernick_supercell_virtual_327_stropt.cif
# Processed: geller-wernick_supercell_virtual_897_stropt.cif
# Processed: geller-wernick_supercell_virtual_599_stropt.cif
# Processed: geller-wernick_supercell_virtual_684_stropt.cif
# Processed: geller-wernick_supercell_virtual_292_stropt.cif
# Processed: geller-wernick_supercell_virtual_452_stropt.cif
# Processed: geller-wernick_supercell_virtual_126_stropt.cif
# Processed: geller-wernick_supercell_virtual_948_stropt.cif
# Processed: geller-wernick_supercell_virtual_714_stropt.cif
# Processed: geller-wernick_supercell_virtual_938_stropt.cif
# Processed: geller-wernick_supercell_virtual_933_stropt.cif
# Processed: geller-wernick_supercell_virtual_323_stropt.cif
# Processed: geller-wernick_supercell_virtual_722_stropt.cif
# Processed: geller-wernick_supercell_virtual_143_stropt.cif
# Processed: geller-wernick_supercell_virtual_641_stropt.cif
# Processed: geller-wernick_supercell_virtual_631_stropt.cif
# Processed: geller-wernick_supercell_virtual_92_stropt.cif
# Processed: geller-wernick_supercell_virtual_103_stropt.cif
# Processed: geller-wernick_supercell_virtual_942_stropt.cif
# Processed: geller-wernick_supercell_virtual_618_stropt.cif
# Processed: geller-wernick_supercell_virtual_896_stropt.cif
# Processed: geller-wernick_supercell_virtual_576_stropt.cif
# Processed: geller-wernick_supercell_virtual_192_stropt.cif
# Processed: geller-wernick_supercell_virtual_179_stropt.cif
# Processed: geller-wernick_supercell_virtual_121_stropt.cif
# Processed: geller-wernick_supercell_virtual_313_stropt.cif
# Processed: geller-wernick_supercell_virtual_768_stropt.cif
# Processed: geller-wernick_supercell_virtual_507_stropt.cif
# Processed: geller-wernick_supercell_virtual_716_stropt.cif
# Processed: geller-wernick_supercell_virtual_198_stropt.cif
# Processed: geller-wernick_supercell_virtual_828_stropt.cif
# Processed: geller-wernick_supercell_virtual_342_stropt.cif
# Processed: geller-wernick_supercell_virtual_840_stropt.cif
# Processed: geller-wernick_supercell_virtual_967_stropt.cif
# Processed: geller-wernick_supercell_virtual_297_stropt.cif
# Processed: geller-wernick_supercell_virtual_846_stropt.cif
# Processed: geller-wernick_supercell_virtual_587_stropt.cif
# Processed: geller-wernick_supercell_virtual_474_stropt.cif
# Processed: geller-wernick_supercell_virtual_858_stropt.cif
# Processed: geller-wernick_supercell_virtual_129_stropt.cif
# Processed: geller-wernick_supercell_virtual_911_stropt.cif
# Processed: geller-wernick_supercell_virtual_93_stropt.cif
# Processed: geller-wernick_supercell_virtual_119_stropt.cif
# Processed: geller-wernick_supercell_virtual_612_stropt.cif
# Processed: geller-wernick_supercell_virtual_966_stropt.cif
# Processed: geller-wernick_supercell_virtual_589_stropt.cif
# Processed: geller-wernick_supercell_virtual_468_stropt.cif
# Processed: geller-wernick_supercell_virtual_207_stropt.cif
# Processed: geller-wernick_supercell_virtual_767_stropt.cif
# Processed: geller-wernick_supercell_virtual_232_stropt.cif
# Processed: geller-wernick_supercell_virtual_405_stropt.cif
# Processed: geller-wernick_supercell_virtual_443_stropt.cif
# Processed: geller-wernick_supercell_virtual_348_stropt.cif
# Processed: geller-wernick_supercell_virtual_400_stropt.cif
# Processed: geller-wernick_supercell_virtual_957_stropt.cif
# Processed: geller-wernick_supercell_virtual_225_stropt.cif
# Processed: geller-wernick_supercell_virtual_241_stropt.cif
# Processed: geller-wernick_supercell_virtual_560_stropt.cif
# Processed: geller-wernick_supercell_virtual_177_stropt.cif
# Processed: geller-wernick_supercell_virtual_867_stropt.cif
# Processed: geller-wernick_supercell_virtual_47_stropt.cif
# Processed: geller-wernick_supercell_virtual_1_stropt.cif
# Processed: geller-wernick_supercell_virtual_205_stropt.cif
# Processed: geller-wernick_supercell_virtual_289_stropt.cif
# Processed: geller-wernick_supercell_virtual_26_stropt.cif
# Processed: geller-wernick_supercell_virtual_264_stropt.cif
# Processed: geller-wernick_supercell_virtual_436_stropt.cif
# Processed: geller-wernick_supercell_virtual_810_stropt.cif
# Processed: geller-wernick_supercell_virtual_218_stropt.cif
# Processed: geller-wernick_supercell_virtual_953_stropt.cif
# Processed: geller-wernick_supercell_virtual_477_stropt.cif
# Processed: geller-wernick_supercell_virtual_349_stropt.cif
# Processed: geller-wernick_supercell_virtual_842_stropt.cif
# Processed: geller-wernick_supercell_virtual_463_stropt.cif
# Processed: geller-wernick_supercell_virtual_172_stropt.cif
# Processed: geller-wernick_supercell_virtual_234_stropt.cif
# Processed: geller-wernick_supercell_virtual_314_stropt.cif
# Processed: geller-wernick_supercell_virtual_371_stropt.cif
# Processed: geller-wernick_supercell_virtual_783_stropt.cif
# Processed: geller-wernick_supercell_virtual_536_stropt.cif
# Processed: geller-wernick_supercell_virtual_88_stropt.cif
# Processed: geller-wernick_supercell_virtual_321_stropt.cif
# Processed: geller-wernick_supercell_virtual_695_stropt.cif
# Processed: geller-wernick_supercell_virtual_547_stropt.cif
# Processed: geller-wernick_supercell_virtual_31_stropt.cif
# Processed: geller-wernick_supercell_virtual_160_stropt.cif
# Processed: geller-wernick_supercell_virtual_820_stropt.cif
# Processed: geller-wernick_supercell_virtual_509_stropt.cif
# Processed: geller-wernick_supercell_virtual_17_stropt.cif
# Processed: geller-wernick_supercell_virtual_147_stropt.cif
# Processed: geller-wernick_supercell_virtual_853_stropt.cif
# Processed: geller-wernick_supercell_virtual_28_stropt.cif
# Processed: geller-wernick_supercell_virtual_57_stropt.cif
# Processed: geller-wernick_supercell_virtual_523_stropt.cif
# Processed: geller-wernick_supercell_virtual_956_stropt.cif
# Processed: geller-wernick_supercell_virtual_365_stropt.cif
# Processed: geller-wernick_supercell_virtual_545_stropt.cif
# Processed: geller-wernick_supercell_virtual_283_stropt.cif
# Processed: geller-wernick_supercell_virtual_924_stropt.cif
# Processed: geller-wernick_supercell_virtual_651_stropt.cif
# Processed: geller-wernick_supercell_virtual_115_stropt.cif
# Processed: geller-wernick_supercell_virtual_272_stropt.cif
# Processed: geller-wernick_supercell_virtual_212_stropt.cif
# Processed: geller-wernick_supercell_virtual_582_stropt.cif
# Processed: geller-wernick_supercell_virtual_50_stropt.cif
# Processed: geller-wernick_supercell_virtual_97_stropt.cif
# Processed: geller-wernick_supercell_virtual_912_stropt.cif
# Processed: geller-wernick_supercell_virtual_355_stropt.cif
# Processed: geller-wernick_supercell_virtual_639_stropt.cif
# Processed: geller-wernick_supercell_virtual_663_stropt.cif
# Processed: geller-wernick_supercell_virtual_913_stropt.cif
# Processed: geller-wernick_supercell_virtual_112_stropt.cif
# Processed: geller-wernick_supercell_virtual_573_stropt.cif
# Processed: geller-wernick_supercell_virtual_210_stropt.cif
# Processed: geller-wernick_supercell_virtual_613_stropt.cif
# Processed: geller-wernick_supercell_virtual_520_stropt.cif
# Processed: geller-wernick_supercell_virtual_619_stropt.cif
# Processed: geller-wernick_supercell_virtual_640_stropt.cif
# Processed: geller-wernick_supercell_virtual_959_stropt.cif
# Processed: geller-wernick_supercell_virtual_437_stropt.cif
# Processed: geller-wernick_supercell_virtual_581_stropt.cif
# Processed: geller-wernick_supercell_virtual_438_stropt.cif
# Processed: geller-wernick_supercell_virtual_243_stropt.cif
# Processed: geller-wernick_supercell_virtual_658_stropt.cif
# Processed: geller-wernick_supercell_virtual_434_stropt.cif
# Processed: geller-wernick_supercell_virtual_669_stropt.cif
# Processed: geller-wernick_supercell_virtual_185_stropt.cif
# Processed: geller-wernick_supercell_virtual_489_stropt.cif
# Processed: geller-wernick_supercell_virtual_423_stropt.cif
# Processed: geller-wernick_supercell_virtual_240_stropt.cif
# Processed: geller-wernick_supercell_virtual_804_stropt.cif
# Processed: geller-wernick_supercell_virtual_756_stropt.cif
# Processed: geller-wernick_supercell_virtual_676_stropt.cif
# Processed: geller-wernick_supercell_virtual_414_stropt.cif
# Processed: geller-wernick_supercell_virtual_645_stropt.cif
# Processed: geller-wernick_supercell_virtual_152_stropt.cif
# Processed: geller-wernick_supercell_virtual_108_stropt.cif
# Processed: geller-wernick_supercell_virtual_458_stropt.cif
# Processed: geller-wernick_supercell_virtual_675_stropt.cif
# Processed: geller-wernick_supercell_virtual_462_stropt.cif
# Processed: geller-wernick_supercell_virtual_79_stropt.cif
# Processed: geller-wernick_supercell_virtual_626_stropt.cif
# Processed: geller-wernick_supercell_virtual_384_stropt.cif
# Processed: geller-wernick_supercell_virtual_538_stropt.cif
# Processed: geller-wernick_supercell_virtual_184_stropt.cif
# Processed: geller-wernick_supercell_virtual_781_stropt.cif
# Processed: geller-wernick_supercell_virtual_440_stropt.cif
# Processed: geller-wernick_supercell_virtual_164_stropt.cif
# Processed: geller-wernick_supercell_virtual_380_stropt.cif
# Processed: geller-wernick_supercell_virtual_216_stropt.cif
# Processed: geller-wernick_supercell_virtual_872_stropt.cif
# Processed: geller-wernick_supercell_virtual_588_stropt.cif
# Processed: geller-wernick_supercell_virtual_422_stropt.cif
# Processed: geller-wernick_supercell_virtual_154_stropt.cif
# Processed: geller-wernick_supercell_virtual_694_stropt.cif
# Processed: geller-wernick_supercell_virtual_854_stropt.cif
# Processed: geller-wernick_supercell_virtual_227_stropt.cif
# Processed: geller-wernick_supercell_virtual_594_stropt.cif
# Processed: geller-wernick_supercell_virtual_800_stropt.cif
# Processed: geller-wernick_supercell_virtual_974_stropt.cif
# Processed: geller-wernick_supercell_virtual_723_stropt.cif
# Processed: geller-wernick_supercell_virtual_635_stropt.cif
# Processed: geller-wernick_supercell_virtual_515_stropt.cif
# Processed: geller-wernick_supercell_virtual_284_stropt.cif
# Processed: geller-wernick_supercell_virtual_590_stropt.cif
# Processed: geller-wernick_supercell_virtual_123_stropt.cif
# Processed: geller-wernick_supercell_virtual_451_stropt.cif
# Processed: geller-wernick_supercell_virtual_832_stropt.cif
# Processed: geller-wernick_supercell_virtual_865_stropt.cif
# Processed: geller-wernick_supercell_virtual_261_stropt.cif
# Processed: geller-wernick_supercell_virtual_610_stropt.cif
# Processed: geller-wernick_supercell_virtual_432_stropt.cif
# Processed: geller-wernick_supercell_virtual_951_stropt.cif
# Processed: geller-wernick_supercell_virtual_382_stropt.cif
# Processed: geller-wernick_supercell_virtual_159_stropt.cif
# Processed: geller-wernick_supercell_virtual_687_stropt.cif
# Processed: geller-wernick_supercell_virtual_575_stropt.cif
# Processed: geller-wernick_supercell_virtual_583_stropt.cif
# Processed: geller-wernick_supercell_virtual_661_stropt.cif
# Processed: geller-wernick_supercell_virtual_375_stropt.cif
# Processed: geller-wernick_supercell_virtual_719_stropt.cif
# Processed: geller-wernick_supercell_virtual_795_stropt.cif
# Processed: geller-wernick_supercell_virtual_891_stropt.cif
# Processed: geller-wernick_supercell_virtual_60_stropt.cif
# Processed: geller-wernick_supercell_virtual_579_stropt.cif
# Processed: geller-wernick_supercell_virtual_597_stropt.cif
# Processed: geller-wernick_supercell_virtual_43_stropt.cif
# Processed: geller-wernick_supercell_virtual_132_stropt.cif
# Processed: geller-wernick_supercell_virtual_317_stropt.cif
# Processed: geller-wernick_supercell_virtual_986_stropt.cif
# Processed: geller-wernick_supercell_virtual_877_stropt.cif
# Processed: geller-wernick_supercell_virtual_56_stropt.cif
# Processed: geller-wernick_supercell_virtual_962_stropt.cif
# Processed: geller-wernick_supercell_virtual_936_stropt.cif
# Processed: geller-wernick_supercell_virtual_280_stropt.cif
# Processed: geller-wernick_supercell_virtual_627_stropt.cif
# Processed: geller-wernick_supercell_virtual_41_stropt.cif
# Processed: geller-wernick_supercell_virtual_151_stropt.cif
# Processed: geller-wernick_supercell_virtual_987_stropt.cif
# Processed: geller-wernick_supercell_virtual_460_stropt.cif
# Processed: geller-wernick_supercell_virtual_789_stropt.cif
# Processed: geller-wernick_supercell_virtual_976_stropt.cif
# Processed: geller-wernick_supercell_virtual_138_stropt.cif
# Processed: geller-wernick_supercell_virtual_352_stropt.cif
# Processed: geller-wernick_supercell_virtual_86_stropt.cif
# Processed: geller-wernick_supercell_virtual_69_stropt.cif
# Processed: geller-wernick_supercell_virtual_428_stropt.cif
# Processed: geller-wernick_supercell_virtual_410_stropt.cif
# Processed: geller-wernick_supercell_virtual_521_stropt.cif
# Processed: geller-wernick_supercell_virtual_254_stropt.cif
# Processed: geller-wernick_supercell_virtual_793_stropt.cif
# Processed: geller-wernick_supercell_virtual_796_stropt.cif
# Processed: geller-wernick_supercell_virtual_74_stropt.cif
# Processed: geller-wernick_supercell_virtual_860_stropt.cif
# Processed: geller-wernick_supercell_virtual_35_stropt.cif
# Processed: geller-wernick_supercell_virtual_577_stropt.cif
# Processed: geller-wernick_supercell_virtual_702_stropt.cif
# Processed: geller-wernick_supercell_virtual_303_stropt.cif
# Processed: geller-wernick_supercell_virtual_777_stropt.cif
# Processed: geller-wernick_supercell_virtual_915_stropt.cif
# Processed: geller-wernick_supercell_virtual_101_stropt.cif
# Processed: geller-wernick_supercell_virtual_964_stropt.cif
# Processed: geller-wernick_supercell_virtual_320_stropt.cif
# Processed: geller-wernick_supercell_virtual_18_stropt.cif
# Processed: geller-wernick_supercell_virtual_178_stropt.cif
# Processed: geller-wernick_supercell_virtual_190_stropt.cif
# Processed: geller-wernick_supercell_virtual_170_stropt.cif
# Processed: geller-wernick_supercell_virtual_236_stropt.cif
# Processed: geller-wernick_supercell_virtual_429_stropt.cif
# Processed: geller-wernick_supercell_virtual_411_stropt.cif
# Processed: geller-wernick_supercell_virtual_141_stropt.cif
# Processed: geller-wernick_supercell_virtual_109_stropt.cif
# Processed: geller-wernick_supercell_virtual_633_stropt.cif
# Processed: geller-wernick_supercell_virtual_570_stropt.cif
# Processed: geller-wernick_supercell_virtual_946_stropt.cif
# Processed: geller-wernick_supercell_virtual_759_stropt.cif
# Processed: geller-wernick_supercell_virtual_67_stropt.cif
# Processed: geller-wernick_supercell_virtual_614_stropt.cif
# Processed: geller-wernick_supercell_virtual_935_stropt.cif
# Processed: geller-wernick_supercell_virtual_295_stropt.cif
# Processed: geller-wernick_supercell_virtual_416_stropt.cif
# Processed: geller-wernick_supercell_virtual_346_stropt.cif
# Processed: geller-wernick_supercell_virtual_396_stropt.cif
# Processed: geller-wernick_supercell_virtual_757_stropt.cif
# Processed: geller-wernick_supercell_virtual_255_stropt.cif
# Processed: geller-wernick_supercell_virtual_992_stropt.cif
# Processed: geller-wernick_supercell_virtual_569_stropt.cif
# Processed: geller-wernick_supercell_virtual_988_stropt.cif
# Processed: geller-wernick_supercell_virtual_120_stropt.cif
# Processed: geller-wernick_supercell_virtual_940_stropt.cif
# Processed: geller-wernick_supercell_virtual_829_stropt.cif
# Processed: geller-wernick_supercell_virtual_632_stropt.cif
# Processed: geller-wernick_supercell_virtual_815_stropt.cif
# Processed: geller-wernick_supercell_virtual_524_stropt.cif
# Processed: geller-wernick_supercell_virtual_881_stropt.cif
# Processed: geller-wernick_supercell_virtual_293_stropt.cif
# Processed: geller-wernick_supercell_virtual_137_stropt.cif
# Processed: geller-wernick_supercell_virtual_395_stropt.cif
# Processed: geller-wernick_supercell_virtual_895_stropt.cif
# Processed: geller-wernick_supercell_virtual_666_stropt.cif
# Processed: geller-wernick_supercell_virtual_530_stropt.cif
# Processed: geller-wernick_supercell_virtual_634_stropt.cif
# Processed: geller-wernick_supercell_virtual_693_stropt.cif
# Processed: geller-wernick_supercell_virtual_231_stropt.cif
# Processed: geller-wernick_supercell_virtual_888_stropt.cif
# Processed: geller-wernick_supercell_virtual_770_stropt.cif
# Processed: geller-wernick_supercell_virtual_171_stropt.cif
# Processed: geller-wernick_supercell_virtual_928_stropt.cif
# Processed: geller-wernick_supercell_virtual_836_stropt.cif
# Processed: geller-wernick_supercell_virtual_107_stropt.cif
# Processed: geller-wernick_supercell_virtual_38_stropt.cif
# Processed: geller-wernick_supercell_virtual_683_stropt.cif
# Processed: geller-wernick_supercell_virtual_162_stropt.cif
# Processed: geller-wernick_supercell_virtual_922_stropt.cif
# Processed: geller-wernick_supercell_virtual_144_stropt.cif
# Processed: geller-wernick_supercell_virtual_685_stropt.cif
# Processed: geller-wernick_supercell_virtual_191_stropt.cif
# Processed: geller-wernick_supercell_virtual_565_stropt.cif
# Processed: geller-wernick_supercell_virtual_271_stropt.cif
# Processed: geller-wernick_supercell_virtual_165_stropt.cif
# Processed: geller-wernick_supercell_virtual_754_stropt.cif
# Processed: geller-wernick_supercell_virtual_932_stropt.cif
# Processed: geller-wernick_supercell_virtual_544_stropt.cif
# Processed: geller-wernick_supercell_virtual_262_stropt.cif
# Processed: geller-wernick_supercell_virtual_505_stropt.cif
# Processed: geller-wernick_supercell_virtual_381_stropt.cif
# Processed: geller-wernick_supercell_virtual_36_stropt.cif
# Processed: geller-wernick_supercell_virtual_139_stropt.cif
# Processed: geller-wernick_supercell_virtual_550_stropt.cif
# Processed: geller-wernick_supercell_virtual_833_stropt.cif
# Processed: geller-wernick_supercell_virtual_886_stropt.cif
# Processed: geller-wernick_supercell_virtual_427_stropt.cif
# Processed: geller-wernick_supercell_virtual_46_stropt.cif
# Processed: geller-wernick_supercell_virtual_790_stropt.cif
# Processed: geller-wernick_supercell_virtual_298_stropt.cif
# Processed: geller-wernick_supercell_virtual_937_stropt.cif
# Processed: geller-wernick_supercell_virtual_798_stropt.cif
# Processed: geller-wernick_supercell_virtual_181_stropt.cif
# Processed: geller-wernick_supercell_virtual_734_stropt.cif
# Processed: geller-wernick_supercell_virtual_859_stropt.cif
# Processed: geller-wernick_supercell_virtual_299_stropt.cif
# Processed: geller-wernick_supercell_virtual_475_stropt.cif
# Processed: geller-wernick_supercell_virtual_818_stropt.cif
# Processed: geller-wernick_supercell_virtual_923_stropt.cif
# Processed: geller-wernick_supercell_virtual_665_stropt.cif
# Processed: geller-wernick_supercell_virtual_345_stropt.cif
# Processed: geller-wernick_supercell_virtual_21_stropt.cif
# Processed: geller-wernick_supercell_virtual_187_stropt.cif
# Processed: geller-wernick_supercell_virtual_883_stropt.cif
# Processed: geller-wernick_supercell_virtual_309_stropt.cif
# Processed: geller-wernick_supercell_virtual_638_stropt.cif
# Processed: geller-wernick_supercell_virtual_441_stropt.cif
# Processed: geller-wernick_supercell_virtual_105_stropt.cif
# Processed: geller-wernick_supercell_virtual_268_stropt.cif
# Processed: geller-wernick_supercell_virtual_233_stropt.cif
# Processed: geller-wernick_supercell_virtual_697_stropt.cif
# Processed: geller-wernick_supercell_virtual_823_stropt.cif
# Processed: geller-wernick_supercell_virtual_361_stropt.cif
# Processed: geller-wernick_supercell_virtual_29_stropt.cif
# Processed: geller-wernick_supercell_virtual_652_stropt.cif
# Processed: geller-wernick_supercell_virtual_412_stropt.cif
# Processed: geller-wernick_supercell_virtual_692_stropt.cif
# Processed: geller-wernick_supercell_virtual_186_stropt.cif
# Processed: geller-wernick_supercell_virtual_548_stropt.cif
# Processed: geller-wernick_supercell_virtual_166_stropt.cif
# Processed: geller-wernick_supercell_virtual_409_stropt.cif
# Processed: geller-wernick_supercell_virtual_122_stropt.cif
# Processed: geller-wernick_supercell_virtual_884_stropt.cif
# Processed: geller-wernick_supercell_virtual_949_stropt.cif
# Processed: geller-wernick_supercell_virtual_954_stropt.cif
# Processed: geller-wernick_supercell_virtual_417_stropt.cif
# Processed: geller-wernick_supercell_virtual_876_stropt.cif
# Processed: geller-wernick_supercell_virtual_503_stropt.cif
# Processed: geller-wernick_supercell_virtual_947_stropt.cif
# Processed: geller-wernick_supercell_virtual_927_stropt.cif
# Processed: geller-wernick_supercell_virtual_484_stropt.cif
# Processed: geller-wernick_supercell_virtual_209_stropt.cif
# Processed: geller-wernick_supercell_virtual_301_stropt.cif
# Processed: geller-wernick_supercell_virtual_404_stropt.cif
# Processed: geller-wernick_supercell_virtual_534_stropt.cif
# Processed: geller-wernick_supercell_virtual_834_stropt.cif
# Processed: geller-wernick_supercell_virtual_749_stropt.cif
# Processed: geller-wernick_supercell_virtual_215_stropt.cif
# Processed: geller-wernick_supercell_virtual_52_stropt.cif
# Processed: geller-wernick_supercell_virtual_118_stropt.cif
# Processed: geller-wernick_supercell_virtual_616_stropt.cif
# Processed: geller-wernick_supercell_virtual_426_stropt.cif
# Processed: geller-wernick_supercell_virtual_0_stropt.cif
# Processed: geller-wernick_supercell_virtual_866_stropt.cif
# Processed: geller-wernick_supercell_virtual_831_stropt.cif
# Processed: geller-wernick_supercell_virtual_34_stropt.cif
# Processed: geller-wernick_supercell_virtual_300_stropt.cif
# Processed: geller-wernick_supercell_virtual_9_stropt.cif
# Processed: geller-wernick_supercell_virtual_561_stropt.cif
# Processed: geller-wernick_supercell_virtual_322_stropt.cif
# Processed: geller-wernick_supercell_virtual_769_stropt.cif
# Processed: geller-wernick_supercell_virtual_526_stropt.cif
# Processed: geller-wernick_supercell_virtual_269_stropt.cif
# Processed: geller-wernick_supercell_virtual_558_stropt.cif
# Processed: geller-wernick_supercell_virtual_512_stropt.cif
# Processed: geller-wernick_supercell_virtual_369_stropt.cif
# Processed: geller-wernick_supercell_virtual_978_stropt.cif
# Processed: geller-wernick_supercell_virtual_637_stropt.cif
# Processed: geller-wernick_supercell_virtual_850_stropt.cif
# Processed: geller-wernick_supercell_virtual_421_stropt.cif
# Processed: geller-wernick_supercell_virtual_739_stropt.cif
# Processed: geller-wernick_supercell_virtual_393_stropt.cif
# Processed: geller-wernick_supercell_virtual_715_stropt.cif
# Processed: geller-wernick_supercell_virtual_653_stropt.cif
# Processed: geller-wernick_supercell_virtual_465_stropt.cif
# Processed: geller-wernick_supercell_virtual_712_stropt.cif
# Processed: geller-wernick_supercell_virtual_708_stropt.cif
# Processed: geller-wernick_supercell_virtual_45_stropt.cif
# Processed: geller-wernick_supercell_virtual_902_stropt.cif
# Processed: geller-wernick_supercell_virtual_733_stropt.cif
# Processed: geller-wernick_supercell_virtual_445_stropt.cif
# Processed: geller-wernick_supercell_virtual_75_stropt.cif
# Processed: geller-wernick_supercell_virtual_595_stropt.cif
# Processed: geller-wernick_supercell_virtual_306_stropt.cif
# Processed: geller-wernick_supercell_virtual_258_stropt.cif
# Processed: geller-wernick_supercell_virtual_374_stropt.cif
# Processed: geller-wernick_supercell_virtual_279_stropt.cif
# Processed: geller-wernick_supercell_virtual_941_stropt.cif
# Processed: geller-wernick_supercell_virtual_156_stropt.cif
# Processed: geller-wernick_supercell_virtual_249_stropt.cif
# Processed: geller-wernick_supercell_virtual_930_stropt.cif
# Processed: geller-wernick_supercell_virtual_794_stropt.cif
# Processed: geller-wernick_supercell_virtual_979_stropt.cif
# Processed: geller-wernick_supercell_virtual_709_stropt.cif
# Processed: geller-wernick_supercell_virtual_830_stropt.cif
# Processed: geller-wernick_supercell_virtual_730_stropt.cif
# Processed: geller-wernick_supercell_virtual_111_stropt.cif
# Processed: geller-wernick_supercell_virtual_220_stropt.cif
# Processed: geller-wernick_supercell_virtual_14_stropt.cif
# Processed: geller-wernick_supercell_virtual_175_stropt.cif
# Processed: geller-wernick_supercell_virtual_688_stropt.cif
# Processed: geller-wernick_supercell_virtual_270_stropt.cif
# Processed: geller-wernick_supercell_virtual_780_stropt.cif
# Processed: geller-wernick_supercell_virtual_356_stropt.cif
# Processed: geller-wernick_supercell_virtual_758_stropt.cif
# Processed: geller-wernick_supercell_virtual_519_stropt.cif
# Processed: geller-wernick_supercell_virtual_862_stropt.cif
# Processed: geller-wernick_supercell_virtual_650_stropt.cif
# Processed: geller-wernick_supercell_virtual_287_stropt.cif
# Processed: geller-wernick_supercell_virtual_880_stropt.cif
# Processed: geller-wernick_supercell_virtual_73_stropt.cif
# Processed: geller-wernick_supercell_virtual_929_stropt.cif
# Processed: geller-wernick_supercell_virtual_339_stropt.cif
# Processed: geller-wernick_supercell_virtual_727_stropt.cif
# Processed: geller-wernick_supercell_virtual_219_stropt.cif
# Processed: geller-wernick_supercell_virtual_971_stropt.cif
# Processed: geller-wernick_supercell_virtual_743_stropt.cif
# Processed: geller-wernick_supercell_virtual_562_stropt.cif
# Processed: geller-wernick_supercell_virtual_180_stropt.cif
# Processed: geller-wernick_supercell_virtual_294_stropt.cif
# Processed: geller-wernick_supercell_virtual_114_stropt.cif
# Processed: geller-wernick_supercell_virtual_466_stropt.cif
# Processed: geller-wernick_supercell_virtual_282_stropt.cif
# Processed: geller-wernick_supercell_virtual_952_stropt.cif
# Processed: geller-wernick_supercell_virtual_392_stropt.cif
# Processed: geller-wernick_supercell_virtual_256_stropt.cif
# Processed: geller-wernick_supercell_virtual_686_stropt.cif
# Processed: geller-wernick_supercell_virtual_648_stropt.cif
# Processed: geller-wernick_supercell_virtual_875_stropt.cif
# Processed: geller-wernick_supercell_virtual_574_stropt.cif
# Processed: geller-wernick_supercell_virtual_257_stropt.cif
# Processed: geller-wernick_supercell_virtual_624_stropt.cif
# Processed: geller-wernick_supercell_virtual_636_stropt.cif
# Processed: geller-wernick_supercell_virtual_782_stropt.cif
# Processed: geller-wernick_supercell_virtual_149_stropt.cif
# Processed: geller-wernick_supercell_virtual_817_stropt.cif
# Processed: geller-wernick_supercell_virtual_77_stropt.cif
# Processed: geller-wernick_supercell_virtual_116_stropt.cif
# Processed: geller-wernick_supercell_virtual_689_stropt.cif
# Processed: geller-wernick_supercell_virtual_6_stropt.cif
# Processed: geller-wernick_supercell_virtual_61_stropt.cif
# Processed: geller-wernick_supercell_virtual_245_stropt.cif
# Processed: geller-wernick_supercell_virtual_242_stropt.cif
# Processed: geller-wernick_supercell_virtual_3_stropt.cif
# Processed: geller-wernick_supercell_virtual_729_stropt.cif
# Processed: geller-wernick_supercell_virtual_444_stropt.cif
# Processed: geller-wernick_supercell_virtual_731_stropt.cif
# Processed: geller-wernick_supercell_virtual_771_stropt.cif
# Processed: geller-wernick_supercell_virtual_372_stropt.cif
# Processed: geller-wernick_supercell_virtual_604_stropt.cif
# Processed: geller-wernick_supercell_virtual_792_stropt.cif
# Processed: geller-wernick_supercell_virtual_252_stropt.cif
# Processed: geller-wernick_supercell_virtual_910_stropt.cif
# Processed: geller-wernick_supercell_virtual_711_stropt.cif
# Processed: geller-wernick_supercell_virtual_106_stropt.cif
# Processed: geller-wernick_supercell_virtual_373_stropt.cif
# Processed: geller-wernick_supercell_virtual_555_stropt.cif
# Processed: geller-wernick_supercell_virtual_656_stropt.cif
# Processed: geller-wernick_supercell_virtual_90_stropt.cif
# Processed: geller-wernick_supercell_virtual_580_stropt.cif
# Processed: geller-wernick_supercell_virtual_698_stropt.cif
# Processed: geller-wernick_supercell_virtual_71_stropt.cif
# Processed: geller-wernick_supercell_virtual_263_stropt.cif
# Processed: geller-wernick_supercell_virtual_546_stropt.cif
# Processed: geller-wernick_supercell_virtual_774_stropt.cif
# Processed: geller-wernick_supercell_virtual_963_stropt.cif
# Processed: geller-wernick_supercell_virtual_224_stropt.cif
# Processed: geller-wernick_supercell_virtual_430_stropt.cif
# Processed: geller-wernick_supercell_virtual_364_stropt.cif
# Processed: geller-wernick_supercell_virtual_826_stropt.cif
# Processed: geller-wernick_supercell_virtual_378_stropt.cif
# Processed: geller-wernick_supercell_virtual_894_stropt.cif
# Processed: geller-wernick_supercell_virtual_307_stropt.cif
# Processed: geller-wernick_supercell_virtual_518_stropt.cif
# Processed: geller-wernick_supercell_virtual_564_stropt.cif
# Processed: geller-wernick_supercell_virtual_330_stropt.cif
# Processed: geller-wernick_supercell_virtual_312_stropt.cif
# Processed: geller-wernick_supercell_virtual_678_stropt.cif
# Processed: geller-wernick_supercell_virtual_431_stropt.cif
# Processed: geller-wernick_supercell_virtual_49_stropt.cif
# Processed: geller-wernick_supercell_virtual_267_stropt.cif
# Processed: geller-wernick_supercell_virtual_96_stropt.cif
# Processed: geller-wernick_supercell_virtual_248_stropt.cif
# Processed: geller-wernick_supercell_virtual_717_stropt.cif
# Processed: geller-wernick_supercell_virtual_273_stropt.cif
# Processed: geller-wernick_supercell_virtual_302_stropt.cif
# Processed: geller-wernick_supercell_virtual_228_stropt.cif
# Processed: geller-wernick_supercell_virtual_554_stropt.cif
# Processed: geller-wernick_supercell_virtual_296_stropt.cif
# Processed: geller-wernick_supercell_virtual_983_stropt.cif
# Processed: geller-wernick_supercell_virtual_732_stropt.cif
# Processed: geller-wernick_supercell_virtual_785_stropt.cif
# Processed: geller-wernick_supercell_virtual_48_stropt.cif
# Processed: geller-wernick_supercell_virtual_600_stropt.cif
# Processed: geller-wernick_supercell_virtual_736_stropt.cif
# Processed: geller-wernick_supercell_virtual_235_stropt.cif
# Processed: geller-wernick_supercell_virtual_230_stropt.cif
# Processed: geller-wernick_supercell_virtual_385_stropt.cif
# Processed: geller-wernick_supercell_virtual_968_stropt.cif
# Processed: geller-wernick_supercell_virtual_672_stropt.cif
# Processed: geller-wernick_supercell_virtual_459_stropt.cif
# Processed: geller-wernick_supercell_virtual_476_stropt.cif
# Processed: geller-wernick_supercell_virtual_319_stropt.cif
# Processed: geller-wernick_supercell_virtual_247_stropt.cif
# Processed: geller-wernick_supercell_virtual_125_stropt.cif
# Processed: geller-wernick_supercell_virtual_532_stropt.cif
# Processed: geller-wernick_supercell_virtual_98_stropt.cif
# Processed: geller-wernick_supercell_virtual_39_stropt.cif
# Processed: geller-wernick_supercell_virtual_917_stropt.cif
# Processed: geller-wernick_supercell_virtual_778_stropt.cif
# Processed: geller-wernick_supercell_virtual_238_stropt.cif
# Processed: geller-wernick_supercell_virtual_22_stropt.cif
# Processed: geller-wernick_supercell_virtual_161_stropt.cif
# Processed: geller-wernick_supercell_virtual_827_stropt.cif
# Processed: geller-wernick_supercell_virtual_975_stropt.cif
# Processed: geller-wernick_supercell_virtual_541_stropt.cif
# Processed: geller-wernick_supercell_virtual_601_stropt.cif
# Processed: geller-wernick_supercell_virtual_244_stropt.cif
# Processed: geller-wernick_supercell_virtual_559_stropt.cif
# Processed: geller-wernick_supercell_virtual_649_stropt.cif
# Processed: geller-wernick_supercell_virtual_53_stropt.cif
# Processed: geller-wernick_supercell_virtual_802_stropt.cif
# Processed: geller-wernick_supercell_virtual_168_stropt.cif
# Processed: geller-wernick_supercell_virtual_424_stropt.cif
# Processed: geller-wernick_supercell_virtual_703_stropt.cif
# Processed: geller-wernick_supercell_virtual_905_stropt.cif
# Processed: geller-wernick_supercell_virtual_408_stropt.cif
# Processed: geller-wernick_supercell_virtual_750_stropt.cif
# Processed: geller-wernick_supercell_virtual_921_stropt.cif
# Processed: geller-wernick_supercell_virtual_776_stropt.cif
# Processed: geller-wernick_supercell_virtual_481_stropt.cif
# Processed: geller-wernick_supercell_virtual_869_stropt.cif
# Processed: geller-wernick_supercell_virtual_744_stropt.cif
# Processed: geller-wernick_supercell_virtual_163_stropt.cif
# Processed: geller-wernick_supercell_virtual_914_stropt.cif
# Processed: geller-wernick_supercell_virtual_104_stropt.cif
# Processed: geller-wernick_supercell_virtual_965_stropt.cif
# Processed: geller-wernick_supercell_virtual_845_stropt.cif
# Processed: geller-wernick_supercell_virtual_390_stropt.cif
# Processed: geller-wernick_supercell_virtual_189_stropt.cif
# Processed: geller-wernick_supercell_virtual_359_stropt.cif
# Processed: geller-wernick_supercell_virtual_406_stropt.cif
# Processed: geller-wernick_supercell_virtual_213_stropt.cif
# Processed: geller-wernick_supercell_virtual_525_stropt.cif
# Processed: geller-wernick_supercell_virtual_399_stropt.cif
# Processed: geller-wernick_supercell_virtual_130_stropt.cif
# Processed: geller-wernick_supercell_virtual_609_stropt.cif
# Processed: geller-wernick_supercell_virtual_492_stropt.cif
# Processed: geller-wernick_supercell_virtual_934_stropt.cif
# Processed: geller-wernick_supercell_virtual_825_stropt.cif
# Processed: geller-wernick_supercell_virtual_816_stropt.cif
# Processed: geller-wernick_supercell_virtual_315_stropt.cif
# Processed: geller-wernick_supercell_virtual_237_stropt.cif
# Processed: geller-wernick_supercell_virtual_325_stropt.cif
# Processed: geller-wernick_supercell_virtual_42_stropt.cif
# Processed: geller-wernick_supercell_virtual_646_stropt.cif
# Processed: geller-wernick_supercell_virtual_239_stropt.cif
# Processed: geller-wernick_supercell_virtual_55_stropt.cif
# Processed: geller-wernick_supercell_virtual_94_stropt.cif
# Processed: geller-wernick_supercell_virtual_674_stropt.cif
# Processed: geller-wernick_supercell_virtual_584_stropt.cif
# Processed: geller-wernick_supercell_virtual_486_stropt.cif
# Processed: geller-wernick_supercell_virtual_784_stropt.cif
# Processed: geller-wernick_supercell_virtual_80_stropt.cif
# Processed: geller-wernick_supercell_virtual_127_stropt.cif
# Processed: geller-wernick_supercell_virtual_316_stropt.cif
# Processed: geller-wernick_supercell_virtual_707_stropt.cif
# Processed: geller-wernick_supercell_virtual_25_stropt.cif
# Processed: geller-wernick_supercell_virtual_945_stropt.cif
# Processed: geller-wernick_supercell_virtual_391_stropt.cif
# Processed: geller-wernick_supercell_virtual_134_stropt.cif
# Processed: geller-wernick_supercell_virtual_200_stropt.cif
# Processed: geller-wernick_supercell_virtual_615_stropt.cif
# Processed: geller-wernick_supercell_virtual_89_stropt.cif
# Processed: geller-wernick_supercell_virtual_660_stropt.cif
# Processed: geller-wernick_supercell_virtual_620_stropt.cif
# Processed: geller-wernick_supercell_virtual_44_stropt.cif
# Processed: geller-wernick_supercell_virtual_996_stropt.cif
# Processed: geller-wernick_supercell_virtual_596_stropt.cif
# Processed: geller-wernick_supercell_virtual_740_stropt.cif
# Processed: geller-wernick_supercell_virtual_630_stropt.cif
# Processed: geller-wernick_supercell_virtual_499_stropt.cif
# Processed: geller-wernick_supercell_virtual_517_stropt.cif
# Processed: geller-wernick_supercell_virtual_389_stropt.cif
# Processed: geller-wernick_supercell_virtual_413_stropt.cif
# Processed: geller-wernick_supercell_virtual_762_stropt.cif
# Processed: geller-wernick_supercell_virtual_813_stropt.cif
# Processed: geller-wernick_supercell_virtual_148_stropt.cif
# Processed: geller-wernick_supercell_virtual_806_stropt.cif
# Processed: geller-wernick_supercell_virtual_919_stropt.cif
# Processed: geller-wernick_supercell_virtual_906_stropt.cif
# Processed: geller-wernick_supercell_virtual_146_stropt.cif
# Processed: geller-wernick_supercell_virtual_893_stropt.cif
# Processed: geller-wernick_supercell_virtual_368_stropt.cif
# Processed: geller-wernick_supercell_virtual_571_stropt.cif
# Processed: geller-wernick_supercell_virtual_383_stropt.cif
# Processed: geller-wernick_supercell_virtual_643_stropt.cif
# Processed: geller-wernick_supercell_virtual_362_stropt.cif
# Processed: geller-wernick_supercell_virtual_878_stropt.cif
# Processed: geller-wernick_supercell_virtual_539_stropt.cif
# Processed: geller-wernick_supercell_virtual_903_stropt.cif
# Processed: geller-wernick_supercell_virtual_808_stropt.cif
# Processed: geller-wernick_supercell_virtual_76_stropt.cif
# Processed: geller-wernick_supercell_virtual_849_stropt.cif
# Processed: geller-wernick_supercell_virtual_563_stropt.cif
# Processed: geller-wernick_supercell_virtual_495_stropt.cif
# Processed: geller-wernick_supercell_virtual_226_stropt.cif
# Processed: geller-wernick_supercell_virtual_761_stropt.cif
# Processed: geller-wernick_supercell_virtual_901_stropt.cif
# Processed: geller-wernick_supercell_virtual_540_stropt.cif
# Processed: geller-wernick_supercell_virtual_841_stropt.cif
# Processed: geller-wernick_supercell_virtual_305_stropt.cif
# Processed: geller-wernick_supercell_virtual_40_stropt.cif
# Results saved to 1000-3x.csv

# %%
import virp.matprop as mprop

# Example usage
folder_path = "test"
output_csv = "test.csv"
mprop.predict_properties(folder_path, output_csv)
# Out:
# C:\Users\andyp\anaconda3\envs\Vaspnest\lib\site-packages\matgl\utils\io.py:126: UserWarning: Incompatible model version detected! The code will continue to load the model but it is recommended that you provide a path to an updated model, increment your @model_version in model.json if you are confident that the changes are not problematic, or clear your ~/.matgl cache using `python -c "import matgl; matgl.clear_cache()"`
#   _check_ver(cls_, v)  # Check version of any subclasses too.
# CHGNet v0.3.0 initialized with 412,525 parameters
# CHGNet will run on cpu
# C:\Users\andyp\anaconda3\envs\Vaspnest\lib\site-packages\pymatgen\core\structure.py:3087: UserWarning: Issues encountered while parsing CIF: 2 fractional coordinates rounded to ideal values to avoid issues with finite precision.
#   struct = parser.parse_structures(primitive=primitive)[0]
# Error processing geller-wernick_supercell_virtual_0_stropt.cif: Buffer dtype mismatch, expected 'const int64_t' but got 'long'
# C:\Users\andyp\anaconda3\envs\Vaspnest\lib\site-packages\pymatgen\core\structure.py:3087: UserWarning: Issues encountered while parsing CIF: 6 fractional coordinates rounded to ideal values to avoid issues with finite precision.
#   struct = parser.parse_structures(primitive=primitive)[0]
# Error processing geller-wernick_supercell_virtual_1_stropt.cif: Buffer dtype mismatch, expected 'const int64_t' but got 'long'
# Error processing geller-wernick_supercell_virtual_2_stropt.cif: Buffer dtype mismatch, expected 'const int64_t' but got 'long'
# Error processing geller-wernick_supercell_virtual_3_stropt.cif: Buffer dtype mismatch, expected 'const int64_t' but got 'long'
# Error processing geller-wernick_supercell_virtual_4_stropt.cif: Buffer dtype mismatch, expected 'const int64_t' but got 'long'
# C:\Users\andyp\anaconda3\envs\Vaspnest\lib\site-packages\pymatgen\core\structure.py:3087: UserWarning: Issues encountered while parsing CIF: 7 fractional coordinates rounded to ideal values to avoid issues with finite precision.
#   struct = parser.parse_structures(primitive=primitive)[0]
# Error processing geller-wernick_supercell_virtual_5_stropt.cif: Buffer dtype mismatch, expected 'const int64_t' but got 'long'
# Results saved to test.csv

# %% [markdown]
# ## Postprocessing

# %%
import pandas as pd
import numpy as np

def expectation_value(csv_path, temperature, properties):
    """
    Calculate Boltzmann-weighted expectation values for specified properties
    
    Args:
        csv_path (str): Path to CSV file
        temperature (float): Temperature in Kelvin
        properties (list): List of column names to calculate expectation values for
        
    Returns:
        tuple: (DataFrame, total_weights, dictionary of expectation values)
    """
    # Read the CSV file
    df = pd.read_csv(csv_path)
    
    # Boltzmann constant in eV/K = 0.00008617
    k_B = 0.00008617
    
    # Calculate weights using the Boltzmann distribution formula
    df['weights'] = np.exp(-df['Total Energy (eV)']/(k_B * temperature))
    
    # Calculate total weights
    total_weights = df['weights'].sum()
    
    # Dictionary to store expectation values
    expectation_values = {}
    
    # Calculate weighted properties and their expectation values
    for prop in properties:
        weighted_col_name = f'weighted_{prop}'
        df[weighted_col_name] = (df[prop] * df['weights']) / total_weights
        expectation_values[prop] = df[weighted_col_name].sum()
    
    return df, expectation_values

# Example usage
if __name__ == "__main__":
    # Replace with your CSV file path
    csv_file = "400-2x.csv"
    temperature = 300  # Set your desired temperature in Kelvin
    
    # List of properties to calculate expectation values for
    properties_list = ["Density", "GLLB-SC Bandgap (eV)", "HSE Bandgap (eV)"]
    
    df, exp_values = expectation_value(csv_file, temperature, properties_list)
    
    print("First few rows of the dataframe with weights and weighted properties:")
    print(df.head())
    print("\nTotal weights:", total_weights)
    print("\nExpectation values:")
    for prop, value in exp_values.items():
        print(f"{prop}: {value:.6f}")
# Out:
# First few rows of the dataframe with weights and weighted properties:
#                                               File  Total Energy (eV)  \
# 0   geller-wernick_supercell_virtual_78_stropt.cif          -3.581327
# 1  geller-wernick_supercell_virtual_222_stropt.cif          -3.584575
# 2   geller-wernick_supercell_virtual_23_stropt.cif          -3.585701
# 3  geller-wernick_supercell_virtual_351_stropt.cif          -3.585306
# 4  geller-wernick_supercell_virtual_140_stropt.cif          -3.586442
#
#     Density  PBE Bandgap (eV)  GLLB-SC Bandgap (eV)  HSE Bandgap (eV)  \
# 0  7.002917         -0.007729              0.569314          0.004754
# 1  7.033245         -0.007371              0.562357          0.012788
# 2  6.914358         -0.007772              0.523779         -0.008054
# 3  7.063052         -0.007512              0.565617          0.016543
# 4  7.065182         -0.007460              0.569464          0.021321
#
#    SCAN Bandgap (eV)       weights  weighted_Density  \
# 0          -0.004004  1.465455e+60          0.014967
# 1          -0.006364  1.661659e+60          0.017044
# 2          -0.006544  1.735589e+60          0.017501
# 3          -0.006126  1.709271e+60          0.017607
# 4          -0.006787  1.786127e+60          0.018404
#
#    weighted_GLLB-SC Bandgap (eV)  weighted_HSE Bandgap (eV)
# 0                       0.001217                   0.000010
# 1                       0.001363                   0.000031
# 2                       0.001326                  -0.000020
# 3                       0.001410                   0.000041
# 4                       0.001483                   0.000056
#
# Total weights: 6.856878070552555e+62
#
# Expectation values:
# Density: 7.022686
# GLLB-SC Bandgap (eV): 0.559384
# HSE Bandgap (eV): 0.014281

# %%
exp_values
# Out:
# {'Density': 7.022685680031463,
#  'GLLB-SC Bandgap (eV)': 0.5593840296483945,
#  'HSE Bandgap (eV)': 0.014280765195099993}

# %%
import pandas as pd
import numpy as np

def expectation_value(csv_path, temperature):
    """
    Calculate Boltzmann-weighted expectation values for all numeric properties
    
    Args:
        csv_path (str): Path to CSV file
        temperature (float): Temperature in Kelvin
        
    Returns:
        tuple: (DataFrame, dictionary of expectation values)
    """
    # Read the CSV file
    df = pd.read_csv(csv_path)
    
    # Boltzmann constant in eV/K = 0.00008617
    k_B = 0.00008617
    
    # Calculate weights using the Boltzmann distribution formula
    df['weights'] = np.exp(-df['Total Energy (eV)']/(k_B * temperature))
    
    # Calculate total weights
    total_weights = df['weights'].sum()
    
    # Dictionary to store expectation values
    expectation_values = {}
    
    # Get all numeric columns except 'Total Energy (eV)' and 'weights'
    excluded_cols = ['File', 'Total Energy (eV)', 'weights']
    numeric_cols = df.select_dtypes(include=[np.number]).columns
    properties = [col for col in numeric_cols if col not in excluded_cols]
    
    # Calculate weighted properties and their expectation values
    for prop in properties:
        weighted_col_name = f'weighted_{prop}'
        df[weighted_col_name] = (df[prop] * df['weights']) / total_weights
        expectation_values[prop] = df[weighted_col_name].sum()
    
    return df, expectation_values

# Example usage
if __name__ == "__main__":
    # Replace with your CSV file path
    csv_file = "400-2x.csv"
    temperature = 300  # Set your desired temperature in Kelvin
    
    df, exp_values = expectation_value(csv_file, temperature)
    
    print("First few rows of the dataframe with weights and weighted properties:")
    print(df.head())
    print("\nExpectation values:")
    for prop, value in exp_values.items():
        print(f"{prop}: {value:.6f}")
# Out:
# First few rows of the dataframe with weights and weighted properties:
#                                               File  Total Energy (eV)  \
# 0   geller-wernick_supercell_virtual_78_stropt.cif          -3.581327
# 1  geller-wernick_supercell_virtual_222_stropt.cif          -3.584575
# 2   geller-wernick_supercell_virtual_23_stropt.cif          -3.585701
# 3  geller-wernick_supercell_virtual_351_stropt.cif          -3.585306
# 4  geller-wernick_supercell_virtual_140_stropt.cif          -3.586442
#
#     Density  PBE Bandgap (eV)  GLLB-SC Bandgap (eV)  HSE Bandgap (eV)  \
# 0  7.002917         -0.007729              0.569314          0.004754
# 1  7.033245         -0.007371              0.562357          0.012788
# 2  6.914358         -0.007772              0.523779         -0.008054
# 3  7.063052         -0.007512              0.565617          0.016543
# 4  7.065182         -0.007460              0.569464          0.021321
#
#    SCAN Bandgap (eV)       weights  weighted_Density  \
# 0          -0.004004  1.465455e+60          0.014967
# 1          -0.006364  1.661659e+60          0.017044
# 2          -0.006544  1.735589e+60          0.017501
# 3          -0.006126  1.709271e+60          0.017607
# 4          -0.006787  1.786127e+60          0.018404
#
#    weighted_PBE Bandgap (eV)  weighted_GLLB-SC Bandgap (eV)  \
# 0                  -0.000017                       0.001217
# 1                  -0.000018                       0.001363
# 2                  -0.000020                       0.001326
# 3                  -0.000019                       0.001410
# 4                  -0.000019                       0.001483
#
#    weighted_HSE Bandgap (eV)  weighted_SCAN Bandgap (eV)
# 0                   0.000010                   -0.000009
# 1                   0.000031                   -0.000015
# 2                  -0.000020                   -0.000017
# 3                   0.000041                   -0.000015
# 4                   0.000056                   -0.000018
#
# Expectation values:
# Density: 7.022686
# PBE Bandgap (eV): -0.007460
# GLLB-SC Bandgap (eV): 0.559384
# HSE Bandgap (eV): 0.014281
# SCAN Bandgap (eV): -0.006077

# %%
exp_values
# Out:
# {'Density': 7.022685680031463,
#  'PBE Bandgap (eV)': -0.007460182489153363,
#  'GLLB-SC Bandgap (eV)': 0.5593840296483945,
#  'HSE Bandgap (eV)': 0.014280765195099993,
#  'SCAN Bandgap (eV)': -0.00607662847607184}

# %%
from virp.matprop import expectation_values

# Example usage
if __name__ == "__main__":
    # Replace with your CSV file path
    csv_file = "400-2x.csv"
    temperature = 300  # Set your desired temperature in Kelvin
    
    df, exp_values = expectation_values(csv_file, temperature)
    
    print("First few rows of the dataframe with weights and weighted properties:")
    print(df.head())
    print("\nExpectation values:")
    for prop, value in exp_values.items():
        print(f"{prop}: {value:.6f}")
# Out:
# First few rows of the dataframe with weights and weighted properties:
#                                               File  Total Energy (eV)  \
# 0   geller-wernick_supercell_virtual_78_stropt.cif          -3.581327
# 1  geller-wernick_supercell_virtual_222_stropt.cif          -3.584575
# 2   geller-wernick_supercell_virtual_23_stropt.cif          -3.585701
# 3  geller-wernick_supercell_virtual_351_stropt.cif          -3.585306
# 4  geller-wernick_supercell_virtual_140_stropt.cif          -3.586442
#
#     Density  PBE Bandgap (eV)  GLLB-SC Bandgap (eV)  HSE Bandgap (eV)  \
# 0  7.002917         -0.007729              0.569314          0.004754
# 1  7.033245         -0.007371              0.562357          0.012788
# 2  6.914358         -0.007772              0.523779         -0.008054
# 3  7.063052         -0.007512              0.565617          0.016543
# 4  7.065182         -0.007460              0.569464          0.021321
#
#    SCAN Bandgap (eV)       weights  weighted_Density  \
# 0          -0.004004  1.465455e+60          0.014967
# 1          -0.006364  1.661659e+60          0.017044
# 2          -0.006544  1.735589e+60          0.017501
# 3          -0.006126  1.709271e+60          0.017607
# 4          -0.006787  1.786127e+60          0.018404
#
#    weighted_PBE Bandgap (eV)  weighted_GLLB-SC Bandgap (eV)  \
# 0                  -0.000017                       0.001217
# 1                  -0.000018                       0.001363
# 2                  -0.000020                       0.001326
# 3                  -0.000019                       0.001410
# 4                  -0.000019                       0.001483
#
#    weighted_HSE Bandgap (eV)  weighted_SCAN Bandgap (eV)
# 0                   0.000010                   -0.000009
# 1                   0.000031                   -0.000015
# 2                  -0.000020                   -0.000017
# 3                   0.000041                   -0.000015
# 4                   0.000056                   -0.000018
#
# Expectation values:
# Density: 7.022686
# PBE Bandgap (eV): -0.007460
# GLLB-SC Bandgap (eV): 0.559384
# HSE Bandgap (eV): 0.014281
# SCAN Bandgap (eV): -0.006077
